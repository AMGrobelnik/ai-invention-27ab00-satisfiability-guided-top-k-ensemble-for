# %% [markdown]
# Title

# %%
Install

# %%
Imports

# %%
Data loading

# %%
Load data

# %% [markdown]
# Config

# %%
Config values

# %% [markdown]
# Helper functions

# %%
Example model

# %% [markdown]
# Mock API

# %%
Mock API code

# %% [markdown]
# Parse FOL

# %%
Parse FOL code

# %% [markdown]
# Compute answer

# %%
Compute answer code

# %% [markdown]
# Baseline

# %%
Baseline code

# %% [markdown]
# Process example

# %%
Process example code

# %% [markdown]
# Run experiment

# %%
Run experiment code

# %% [markdown]
# Results

# %%
Results code
